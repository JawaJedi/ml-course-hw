# %% [markdown]
# ## Home assignment 05: Bagging and OOB score
#
# Please, fill the lines in the code below.
# This is a simplified version of `BaggingRegressor` from `sklearn`. Please, notice, that `sklearn` API is **not preserved**.
#
# Your algorithm should be able to train different instances of the same model class on bootstrapped datasets and to provide [OOB score](https://en.wikipedia.org/wiki/Out-of-bag_error) for the training set.
#
# The model should be passed as model class with no explicit parameters and no parentheses.
#
# Example:
# ```
# import numpy as np
# from sklearn.linear_model import LinearRegression
#
# bagging_regressor = SimplifiedBaggingRegressor(num_bags=10, oob=True)
# bagging_regressor.fit(LinearRegression, X, y)
#
# ```

# %%
import numpy as np

# %%
from sklearn.linear_model import LinearRegression
from tqdm.auto import tqdm
import numpy as np
from random import choices

class SimplifiedBaggingRegressor:
    def __init__(self, num_bags, oob=False):
        self.num_bags = num_bags
        self.oob = oob

    def _generate_splits(self, data: np.ndarray):
        '''
        Generate indices for every bag and store in self.indices_list list
        '''
        self.indices_list = []
        data_length = len(data)
        for bag in range(self.num_bags):
            # Your Code Here
            self.indices_list.append(choices(range(data_length), k = data_length)) #сэмплирование с возвратом
            #self.indices_list.append(np.random.choice(data_length, size=data_length, replace=True)) #сэмплирование с возвратом

    def fit(self, model_constructor, data, target):
        '''
        Fit model on every bag.
        Model constructor with no parameters (and with no ()) is passed to this function.

        example:

        bagging_regressor = SimplifiedBaggingRegressor(num_bags=10, oob=True)
        bagging_regressor.fit(LinearRegression, X, y)
        '''
        self.data = None
        self.target = None
        self._generate_splits(data)
        assert len(set(list(map(len, self.indices_list)))) == 1, 'All bags should be of the same length!'
        assert list(map(len, self.indices_list))[0] == len(
            data), 'All bags should contain `len(data)` number of elements!'
        self.models_list = []
        for bag in range(self.num_bags):
            model = model_constructor()
            #data_bag, target_bag =  0# Your Code Here
            data_bag = data[self.indices_list[bag],:]
            target_bag = target[self.indices_list[bag]]
            self.models_list.append(model.fit(data_bag, target_bag))  # store fitted models here
        if self.oob:
            self.data = data
            self.target = target

    def predict(self, data):
        '''
        Get average prediction for every object from passed dataset
        '''
        # Your code here
        res = []
        for model in self.models_list:
            res.append(model.predict(data))
        return np.average(res, axis=0)

    def _get_oob_predictions_from_every_model(self):
        '''
        Generates list of lists, where list i contains predictions for self.data[i] object
        from all models, which have not seen this object during training phase
        '''
        list_of_predictions_lists = [[] for _ in range(len(self.data))]
        i=0
        for prediction_list in list_of_predictions_lists:
            for bag in range(self.num_bags):
                if not(i in self.indices_list[bag]):
                    prediction_list.append(self.models_list[bag].predict([self.data[i]]))
            i += 1
        self.list_of_predictions_lists = np.array(list_of_predictions_lists, dtype=object)

    def _get_averaged_oob_predictions(self):
        '''
        Compute average prediction for every object from training set.
        If object has been used in all bags on training phase, return None instead of prediction
        '''
        self._get_oob_predictions_from_every_model()
        oob_predictions = []
        for prediction_list in self.list_of_predictions_lists:
            if len(prediction_list) < self.num_bags:
                oob_predictions.append(np.average(prediction_list))
            else:
                oob_predictions.append(None)
        self.oob_predictions = oob_predictions # Your Code Here

    def OOB_score(self):
        '''
        Compute mean square error for all objects, which have at least one prediction
        '''
        self._get_averaged_oob_predictions()
        oob_scores = []
        for i in range(len(self.target)):
            if self.oob_predictions[i] != None:
                oob_scores.append(np.square(self.oob_predictions[i] - self.target[i]))
        return np.nanmean(oob_scores)# Не понял, почему ругается на пустые значения, хотя их отфильтровывает. Но тесты проходит.

# %% [markdown]
# ### Local tests:

# %%
from sklearn.linear_model import LinearRegression
from tqdm.auto import tqdm

# %% [markdown]
# #### Simple tests:

# %%
for _ in tqdm(range(100)):
    X = np.random.randn(2000, 10)
    y = np.mean(X, axis=1)
    bagging_regressor = SimplifiedBaggingRegressor(num_bags=10, oob=True)
    bagging_regressor.fit(LinearRegression, X, y)
    predictions = bagging_regressor.predict(X)
    assert np.mean((predictions - y)**2) < 1e-6, 'Linear dependency should be fitted with almost zero error!'
    assert bagging_regressor.oob, 'OOB feature must be turned on'
    oob_score = bagging_regressor.OOB_score()
    assert oob_score < 1e-6, 'OOB error for linear dependency should be also close to zero!'
    assert abs(
        np.mean(
            list(map(len, bagging_regressor.list_of_predictions_lists))
        ) / bagging_regressor.num_bags - 1/np.exp(1)) < 0.1, 'Probability of missing a bag should be close to theoretical value!'
print('Simple tests done!')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#   1%|          | 1/100 [00:00<01:23,  1.18it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#   2%|▏         | 2/100 [00:01<01:22,  1.19it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#   3%|▎         | 3/100 [00:02<01:21,  1.19it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#   4%|▍         | 4/100 [00:03<01:20,  1.19it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#   5%|▌         | 5/100 [00:04<01:19,  1.20it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#   6%|▌         | 6/100 [00:05<01:18,  1.20it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#   7%|▋         | 7/100 [00:05<01:17,  1.20it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#   8%|▊         | 8/100 [00:06<01:17,  1.19it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#   9%|▉         | 9/100 [00:07<01:15,  1.20it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  10%|█         | 10/100 [00:08<01:15,  1.19it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  11%|█         | 11/100 [00:09<01:15,  1.18it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  12%|█▏        | 12/100 [00:10<01:14,  1.19it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  13%|█▎        | 13/100 [00:10<01:12,  1.19it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  14%|█▍        | 14/100 [00:11<01:11,  1.20it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  15%|█▌        | 15/100 [00:12<01:10,  1.20it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  16%|█▌        | 16/100 [00:13<01:09,  1.21it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  17%|█▋        | 17/100 [00:14<01:08,  1.22it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  18%|█▊        | 18/100 [00:14<01:07,  1.22it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  19%|█▉        | 19/100 [00:15<01:06,  1.23it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  20%|██        | 20/100 [00:16<01:05,  1.23it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  21%|██        | 21/100 [00:17<01:04,  1.23it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  22%|██▏       | 22/100 [00:18<01:03,  1.23it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  23%|██▎       | 23/100 [00:19<01:03,  1.22it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#
  1.22it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  82%|████████▏ | 82/100 [01:07<00:14,  1.22it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  83%|████████▎ | 83/100 [01:08<00:13,  1.23it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  84%|████████▍ | 84/100 [01:09<00:13,  1.23it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  85%|████████▌ | 85/100 [01:10<00:12,  1.22it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  86%|████████▌ | 86/100 [01:10<00:11,  1.23it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  87%|████████▋ | 87/100 [01:11<00:10,  1.22it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  88%|████████▊ | 88/100 [01:12<00:09,  1.22it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  89%|████████▉ | 89/100 [01:13<00:09,  1.21it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  90%|█████████ | 90/100 [01:14<00:08,  1.20it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  91%|█████████ | 91/100 [01:15<00:07,  1.21it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  92%|█████████▏| 92/100 [01:15<00:06,  1.19it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  93%|█████████▎| 93/100 [01:16<00:05,  1.20it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  94%|█████████▍| 94/100 [01:17<00:04,  1.21it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  95%|█████████▌| 95/100 [01:18<00:04,  1.21it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  96%|█████████▌| 96/100 [01:19<00:03,  1.22it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  97%|█████████▋| 97/100 [01:20<00:02,  1.23it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  98%|█████████▊| 98/100 [01:20<00:01,  1.21it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#  99%|█████████▉| 99/100 [01:21<00:00,  1.20it/s]C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\lib\function_base.py:518: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis, **keepdims_kw)
# C:\Users\Timur\.conda\envs\ML\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 100/100 [01:22<00:00,  1.21it/s]
# Simple tests done!

# %% [markdown]
# #### Medium tests

# %%
for _ in tqdm(range(10)):
    X = np.random.randn(200, 150)
    y = np.random.randn(len(X))
    bagging_regressor = SimplifiedBaggingRegressor(num_bags=20, oob=True)
    bagging_regressor.fit(LinearRegression, X, y)
    predictions = bagging_regressor.predict(X)
    average_train_error = np.mean((predictions - y)**2)
    assert bagging_regressor.oob, 'OOB feature must be turned on'
    oob_score = bagging_regressor.OOB_score()
    assert oob_score > average_train_error, 'OOB error must be higher than train error due to overfitting!'
    assert abs(
        np.mean(
            list(map(len, bagging_regressor.list_of_predictions_lists))
        ) / bagging_regressor.num_bags - 1/np.exp(1)) < 0.1, 'Probability of missing a bag should be close to theoretical value!'

print('Medium tests done!')
# Out:
# 100%|██████████| 10/10 [00:01<00:00,  6.23it/s]
# Medium tests done!

# %% [markdown]
# #### Complex tests:

# %%
for _ in tqdm(range(10)):
    X = np.random.randn(2000, 15)
    y = np.random.randn(len(X))
    bagging_regressor = SimplifiedBaggingRegressor(num_bags=100, oob=True)
    bagging_regressor.fit(LinearRegression, X, y)
    predictions = bagging_regressor.predict(X)
    oob_score = bagging_regressor.OOB_score()
    assert abs(
        np.mean(
            list(map(len, bagging_regressor.list_of_predictions_lists))
        ) / bagging_regressor.num_bags - 1/np.exp(1)) < 1e-2, 'Probability of missing a bag should be close to theoretical value!'

print('Complex tests done!')
# Out:
# 100%|██████████| 10/10 [01:21<00:00,  8.15s/it]
# Complex tests done!

# %%
np.mean(
            list(map(len, bagging_regressor.list_of_predictions_lists))
        ) / bagging_regressor.num_bags - 1/np.exp(1)
# Out:
# 0.00035055882855766773

# %% [markdown]
# Great job! Please, save `SimplifiedBaggingRegressor` to  `bagging.py` and submit your solution to the grading system!
